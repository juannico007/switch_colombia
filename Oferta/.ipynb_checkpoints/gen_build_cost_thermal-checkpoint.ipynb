# %%
import pandas as pd

# %%
p_t = pd.read_excel("Plantas termicas.xlsx", sheet_name = "ctermico")

# %%
p_t.head()
# Out:
#    !Num  ...Nombre...  #Uni  Tipo  .PotIns  .GerMin  .GerMax  ..Teif.  \
# 0  1001  BARRANQUILL3     1     0     60.0        0     60.0     5.44
# 1  1003  BARRANQUILL4     1     0     60.0        0     60.0     7.18
# 2  1068        TEBSAB     1     0    791.0        0    791.0     5.70
# 3  1069      TEBSAGIM     1     0    791.0        0    791.0     5.70
# 4  1036      FLORES 1     1     0    160.0        0    160.0     3.76
#
#    ..Ih...  .CVaria  ...  ...2  ...3  ComT  CTransp  StartUp  sfal  NGas  \
# 0    21.24     5.53  ...   NaN   NaN     0        0   16.682     0   NaN
# 1    21.34     5.53  ...   NaN   NaN     0        0   16.682     0   NaN
# 2     9.10     5.53  ...   NaN   NaN     0        0   23.347     0   NaN
# 3     9.10     5.53  ...   0.0   0.0     0        0   23.347     0   NaN
# 4     9.20     5.53  ...   NaN   NaN     0        0   18.203     0   NaN
#
#    NuCC  ..NombreCC..  CoefE.
# 0   NaN           NaN     1.0
# 1   NaN           NaN     NaN
# ...

# %%
#Creación de dataframe vacio para gen_build_cost
gen_bc_t = pd.DataFrame()

# %%
#Mapeo de generation project
gen_bc_t["GENERATION_PROJECT"] = p_t["...Nombre..."]

# %%
#Build year - Aun no esta
num_rows = len(p_t.index)
year = ["." for i in range(num_rows)]
gen_bc_t["build_year"] = year

# %%
#overnight cost - Aun no esta
oc = ["." for i in range(num_rows)]
gen_bc_t["gen_overnight_costs"] = oc

# %%
gen_bc_t
# Out:
#    GENERATION_PROJECT build_year gen_overnight_cost gen_overnight_costs
# 0        BARRANQUILL3          .                  .                   .
# 1        BARRANQUILL4          .                  .                   .
# 2              TEBSAB          .                  .                   .
# 3            TEBSAGIM          .                  .                   .
# 4            FLORES 1          .                  .                   .
# 5           FLORES1GN          .                  .                   .
# 6             FLORES4          .                  .                   .
# 7          FLORES4GIM          .                  .                   .
# 8          CARTAGENA1          .                  .                   .
# 9          CARTAGGAS1          .                  .                   .
# 10         CARTAGENA2          .                  .                   .
# 11         CARTAGGAS2          .                  .                   .
# ...
